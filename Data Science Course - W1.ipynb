# %%
import numpy as np
import pandas as pd

data1 = pd.read_csv("Employee_Addresses.csv")
data1.head
# Out:
# <bound method NDFrame.head of                                                 address  employee_id
# 0         98 Edinburgh St, San Francisco, CA 94112, USA          206
# 1              237 Accacia St, Daly City, CA 94014, USA         2081
# 2          1835 Folsom St, San Francisco, CA 94103, USA          178
# 3        170 Cambridge St, San Francisco, CA 94134, USA           50
# 4           16 Roanoke St, San Francisco, CA 94131, USA         1863
# 5             222 Whittier St, Daly City, CA 94014, USA          485
# 6              13 Hyde St, San Francisco, CA 94102, USA          489
# 7             2919 Geneva Ave, Daly City, CA 94014, USA         1200
# 8           100 Larkin St, San Francisco, CA 94102, USA          336
# 9           230 Murray St, San Francisco, CA 94112, USA         2015
# 10          45 Sanchez St, San Francisco, CA 94114, USA         1526
# 11           2300 16th St, San Francisco, CA 94103, USA           68
# ...

# %%
from pygeocoder import Geocoder
business_geocoder = Geocoder(api_key='AIzaSyAJCsucfK9pP9TCG3-F8ybHuJpWOrC-gug')
business_geocoder.geocode('blah')
def getCoordinate(address):
    return business_geocoder.geocode(address)
dataInput = ["MISSION ST and ITALY AVE  San Francisco, CA 94112, USA" , "MISSION ST and NEW MONTGOMERY ST  San Francisco, CA 94112, USA"]
results = []
for item in dataInput:
    results.append(getCoordinate(item))
print(results[1].coordinates)
# Out:
# (37.7874561, -122.4005234)

# %%
results = list(map(getCoordinate, data1['address'].values.tolist()))
print(results)
# Out:
# [<pygeolib.GeocoderResult object at 0x00000242F2AD3B00>, <pygeolib.GeocoderResult object at 0x00000242EF568588>, <pygeolib.GeocoderResult object at 0x00000242EF533320>, <pygeolib.GeocoderResult object at 0x00000242F2ACEEB8>, <pygeolib.GeocoderResult object at 0x00000242EF478630>, <pygeolib.GeocoderResult object at 0x00000242F2ACE668>, <pygeolib.GeocoderResult object at 0x00000242F2AD3208>, <pygeolib.GeocoderResult object at 0x00000242F2ACEDA0>, <pygeolib.GeocoderResult object at 0x00000242F2ABF2E8>, <pygeolib.GeocoderResult object at 0x00000242F2F0CB70>, <pygeolib.GeocoderResult object at 0x00000242F2ACEF98>, <pygeolib.GeocoderResult object at 0x00000242F2ABF0B8>, <pygeolib.GeocoderResult object at 0x00000242F2ACE630>, <pygeolib.GeocoderResult object at 0x00000242F2AD39B0>, <pygeolib.GeocoderResult object at 0x00000242F2ACE3C8>, <pygeolib.GeocoderResult object at 0x00000242F2ABFF60>, <pygeolib.GeocoderResult object at 0x00000242F2F0C630>, <pygeolib.GeocoderResult object at 0x00000242
# ...

# %%
longitudeList = []
latitudeList = []
for item in results:
    longitudeList.append(item.coordinates[0])
    latitudeList.append(item.coordinates[1])
longitudeSeri = pd.Series(longitudeList)
latitudeSeri = pd.Series(latitudeList)

data1['longitude'] = longitudeSeri.values
data1['latitude'] = latitudeSeri.values

# %%
data1.head
# Out:
# <bound method NDFrame.head of                                                 address  employee_id  \
# 0         98 Edinburgh St, San Francisco, CA 94112, USA          206
# 1              237 Accacia St, Daly City, CA 94014, USA         2081
# 2          1835 Folsom St, San Francisco, CA 94103, USA          178
# 3        170 Cambridge St, San Francisco, CA 94134, USA           50
# 4           16 Roanoke St, San Francisco, CA 94131, USA         1863
# 5             222 Whittier St, Daly City, CA 94014, USA          485
# 6              13 Hyde St, San Francisco, CA 94102, USA          489
# 7             2919 Geneva Ave, Daly City, CA 94014, USA         1200
# 8           100 Larkin St, San Francisco, CA 94102, USA          336
# 9           230 Murray St, San Francisco, CA 94112, USA         2015
# 10          45 Sanchez St, San Francisco, CA 94114, USA         1526
# 11           2300 16th St, San Francisco, CA 94103, USA           68
# ...

# %%
data1.shape
# Out:
# (2191, 4)

# %%
data1['longitude']
# Out:
# 0       37.727475
# 1       37.704205
# 2       37.767932
# 3       37.729642
# 4       37.736240
# 5       37.707408
# 6       37.779231
# 7       37.706755
# 8       37.778956
# 9       37.733454
# 10      37.768459
# 11      37.765905
# 12      37.703834
# 13      37.737010
# 14      37.721365
# 15      37.706085
# 16      37.719440
# 17      37.795134
# 18      37.716133
# 19      37.710407
# 20      37.783293
# 21      37.771399
# 22      37.726692
# 23      37.735124
# 24      37.738377
# 25      37.704638
# 26      37.742780
# 27      37.796434
# 28      37.716945
# 29      37.771110
#           ...
# 2161    37.767946
# 2162    37.743565
# 2163    37.777274
# 2164    37.735797
# 2165    37.792797
# 2166    37.769653
# 2167    37.738265
# 2168    37.735724
# 2169    37.717146
# 2170    37.769967
# 2171    37.719418
# 2172    37.768704
# 2173    37.736626
# 2174    37.715749
# 2175    37.780650
# 2176    37.736065
# 2177    37.767336
# 2178    37.776176
# 2179    37.727907
# ...

# %%
import folium
map_osm = folium.Map(location=[45.5236, -122.6750])

# %%
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data1.drop_duplicates(['employee_id'], keep='last')
# Out:
#                                                 address  employee_id  \
# 0         98 Edinburgh St, San Francisco, CA 94112, USA          206
# 1              237 Accacia St, Daly City, CA 94014, USA         2081
# 2          1835 Folsom St, San Francisco, CA 94103, USA          178
# 3        170 Cambridge St, San Francisco, CA 94134, USA           50
# 4           16 Roanoke St, San Francisco, CA 94131, USA         1863
# 5             222 Whittier St, Daly City, CA 94014, USA          485
# 6              13 Hyde St, San Francisco, CA 94102, USA          489
# 7             2919 Geneva Ave, Daly City, CA 94014, USA         1200
# 8           100 Larkin St, San Francisco, CA 94102, USA          336
# 9           230 Murray St, San Francisco, CA 94112, USA         2015
# 10          45 Sanchez St, San Francisco, CA 94114, USA         1526
# 11           2300 16th St, San Francisco, CA 94103, USA           68
# 12            838 Schwerin St, Daly City, CA 94014, USA         1168
# ...

# %%
map_7 = folium.Map(location=[data1['longitude'][0], data1['latitude'][0]],
                   zoom_start=12,
                   tiles='OpenStreetMap')

# %%
for i in range(0, 1900):
    folium.Marker([data1.iloc[i]['longitude'], data1.iloc[i]['latitude']],
              icon=folium.Icon(color='green')
             ).add_to(map_7)

# %%
map_7
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data2 = pd.read_csv("Potentail_Bust_Stops (2).csv")
data2.head
# Out:
# <bound method NDFrame.head of      Street_One         Street_Two
# 0    MISSION ST          ITALY AVE
# 1    MISSION ST  NEW MONTGOMERY ST
# 2    MISSION ST            01ST ST
# 3    MISSION ST            20TH ST
# 4    MISSION ST         FREMONT ST
# 5    MISSION ST            13TH ST
# 6    MISSION ST            ERIE ST
# 7    MISSION ST           BEALE ST
# 8    MISSION ST           FAIR AVE
# 9    MISSION ST    SAINT MARYS AVE
# 10   MISSION ST         SENECA AVE
# 11   MISSION ST         ANTHONY ST
# 12   MISSION ST     JESSIE EAST ST
# 13   MISSION ST         SILVER AVE
# 14   MISSION ST   MOUNT VERNON AVE
# 15   MISSION ST            30TH ST
# 16   MISSION ST            MAIN ST
# 17   MISSION ST        TRUMBULL ST
# 18   MISSION ST            15TH ST
# 19   MISSION ST        KINGSTON ST
# 20   MISSION ST         TINGLEY ST
# 21   MISSION ST         THERESA ST
# 22   MISSION ST            PARK ST
# 23   MISSION ST          OLIVER ST
# 24   MISSION ST         STEUART ST
# ...

# %%
data2['address'] = data2['Street_One'] + " and " + data2['Street_Two'] + " San Francisco, CA 94112, USA"

# %%
data2.head
# Out:
# <bound method NDFrame.head of      Street_One         Street_Two  \
# 0    MISSION ST          ITALY AVE
# 1    MISSION ST  NEW MONTGOMERY ST
# 2    MISSION ST            01ST ST
# 3    MISSION ST            20TH ST
# 4    MISSION ST         FREMONT ST
# 5    MISSION ST            13TH ST
# 6    MISSION ST            ERIE ST
# 7    MISSION ST           BEALE ST
# 8    MISSION ST           FAIR AVE
# 9    MISSION ST    SAINT MARYS AVE
# 10   MISSION ST         SENECA AVE
# 11   MISSION ST         ANTHONY ST
# 12   MISSION ST     JESSIE EAST ST
# 13   MISSION ST         SILVER AVE
# 14   MISSION ST   MOUNT VERNON AVE
# 15   MISSION ST            30TH ST
# 16   MISSION ST            MAIN ST
# 17   MISSION ST        TRUMBULL ST
# 18   MISSION ST            15TH ST
# 19   MISSION ST        KINGSTON ST
# 20   MISSION ST         TINGLEY ST
# 21   MISSION ST         THERESA ST
# 22   MISSION ST            PARK ST
# 23   MISSION ST          OLIVER ST
# 24   MISSION ST         STEUART ST
# ...

# %%
data2 = data2[data2.Street_Two != '21ST ST']

# %%
results2 = list(map(getCoordinate, data2['address'].values.tolist()))

# %%
longitudeList2 = []
latitudeList2 = []
for item in results2:
    longitudeList2.append(item.coordinates[0])
    latitudeList2.append(item.coordinates[1])
longitudeSeri2 = pd.Series(longitudeList2)
latitudeSeri2 = pd.Series(latitudeList2)

data2['longitude'] = longitudeSeri2.values
data2['latitude'] = latitudeSeri2.values
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
data2.head
# Out:
# <bound method NDFrame.head of      Street_One         Street_Two  \
# 0    MISSION ST          ITALY AVE
# 1    MISSION ST  NEW MONTGOMERY ST
# 2    MISSION ST            01ST ST
# 3    MISSION ST            20TH ST
# 4    MISSION ST         FREMONT ST
# 5    MISSION ST            13TH ST
# 6    MISSION ST            ERIE ST
# 7    MISSION ST           BEALE ST
# 8    MISSION ST           FAIR AVE
# 9    MISSION ST    SAINT MARYS AVE
# 10   MISSION ST         SENECA AVE
# 11   MISSION ST         ANTHONY ST
# 12   MISSION ST     JESSIE EAST ST
# 13   MISSION ST         SILVER AVE
# 14   MISSION ST   MOUNT VERNON AVE
# 15   MISSION ST            30TH ST
# 16   MISSION ST            MAIN ST
# 17   MISSION ST        TRUMBULL ST
# 18   MISSION ST            15TH ST
# 19   MISSION ST        KINGSTON ST
# 20   MISSION ST         TINGLEY ST
# 21   MISSION ST         THERESA ST
# 22   MISSION ST            PARK ST
# 23   MISSION ST          OLIVER ST
# 24   MISSION ST         STEUART ST
# ...

# %%
for i in range(0, 118):
    folium.Marker([data2.iloc[i]['longitude'], data2.iloc[i]['latitude']],
              icon=folium.Icon(color='red')
             ).add_to(map_7)

# %%
map_7
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Some employees in the south are more difficult to go to work.
